# %%
import matplotlib.pyplot as plt
from evaltools.plotting import plot_histogram, draw_arrow
from evaltools.colors import districtr
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
scores = {
    "ensemble": [int(x) for x in np.random.normal(14, 4, size=1000)],
    "citizen": [int(x) for x in np.random.normal(12, 8, size=100)],
    "proposed": [8, 9, 17],
}

proposed_info = {
    "colors": districtr[:len(scores['proposed'])],
    "names": [f"Plan {i+1}" for i in range(len(scores['proposed']))],
}

fig, ax = plt.subplots(figsize=(12,6))
ax = plot_histogram(ax, scores, proposed_info)
draw_arrow(ax, "Dem. advantage", "horizontal", padding=0.1)
text = ax.set_xlabel("Split Counties", fontsize=24)

# %%
means = [int(x) for x in np.random.normal(10, 5, size=8)]

scores = {
    "ensemble": [[int(x) for x in np.random.normal(m, 4, size=1000)] for m in means],
    "proposed": [int(np.random.normal(10, 2)) for _ in means],
}

proposed_info = {
    "colors": districtr[:len(means)],
    "names": [f"Plan {i+1}" for i in range(len(means))],
}

# %%
scores['ensemble']
# Out:
# [[1,
#   1,
#   3,
#   2,
#   1,
#   0,
#   2,
#   4,
#   0,
#   5,
#   -10,
#   11,
#   2,
#   1,
#   0,
#   -2,
#   2,
#   -3,
#   7,
#   0,
#   5,
#   2,
#   12,
#   -2,
#   3,
#   3,
#   3,
#   3,
#   6,
#   2,
#   -2,
#   15,
#   0,
#   -2,
#   9,
#   0,
#   5,
#   0,
#   4,
#   0,
#   1,
#   -1,
#   -3,
#   2,
#   2,
#   2,
#   1,
#   5,
#   -6,
#   2,
#   2,
#   0,
#   6,
#   -8,
#   3,
#   10,
#   2,
#   5,
#   0,
#   3,
#   12,
#   5,
#   6,
#   2,
#   -2,
#   3,
#   0,
#   5,
#   2,
#   6,
#   1,
#   -3,
#   1,
#   3,
#   0,
#   5,
#   -1,
#   8,
#   5,
#   1,
#   1,
#   10,
#   1,
#   4,
#   7,
#   -1,
#   3,
#   -8,
#   6,
#   4,
#   8,
#   2,
#   5,
#   1,
#   0,
#   8,
#   6,
#   -4,
#   -1,
#   0,
#   2,
#   -1,
#   1,
#   -1,
#   6,
#   3,
#   -2,
#   5,
#   7,
#   0,
#   7,
#   5,
#   6,
#   4,
#   5,
#   0,
#   -1,
#   1,
#   -4,
#   3,
#   6,
#   -2,
#   -2,
#   7,
#   0,
#   2,
#   2,
#   2,
#   -5,
#   7,
#   -7,
#   11,
#   8,
#   0,
#   2,
#   1,
#   0,
#   4,
# ...
