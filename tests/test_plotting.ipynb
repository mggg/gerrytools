# %%
import matplotlib.pyplot as plt
from evaltools.plotting import plot_histogram, draw_arrow
from evaltools.plotting.colors import *
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
normal = np.random.normal(loc=14, scale=3, size=100)
ensemble = [int(x) for x in normal]
proposed_scores = [10, 11, 18]
proposed_info = {
    "colors": [burntOrange, sicklyGreen, lightPurple],
    "names": ["Test 1", "Test 2", "Test 3"],
}
scores = {
    "ensemble": ensemble,
    "citizen": [],
    "proposed": proposed_scores,
}

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax = plot_histogram(ax, scores, proposed_info)
draw_arrow(ax, "Dem. advantage", "horizontal", padding=0.1)
ax.set_xlabel("Split Counties", fontsize=24)
# Out:
# Text(0.5, 0, 'Split Counties')
