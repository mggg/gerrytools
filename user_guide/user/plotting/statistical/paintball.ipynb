# %% [markdown]
# # Paintball plots
#
# <style>
# blockquote:has(.notebook-admonition-title) {
#   --notebook-admonition-color: var(--color-admonition-title--note, #087fc7);
#   --notebook-admonition-title-background:
#     var(--color-admonition-title-background--note, rgba(8, 127, 199, 0.18));
#   background: var(--color-admonition-background, transparent);
#   border: 0;
#   border-left: 0.2rem solid var(--notebook-admonition-color);
#   border-radius: 0.2rem;
#   box-shadow: 0 0.2rem 0.5rem rgba(0, 0, 0, 0.05), 0 0 0.0625rem rgba(0, 0, 0, 0.1);
#   font-size: var(--admonition-font-size, 0.8125rem);
#   margin: 1rem auto;
#   overflow: hidden;
#   padding: 0 0.5rem 0.5rem;
# }
# blockquote p:has(> .notebook-admonition-title) {
#   background: var(--notebook-admonition-title-background);
#   font-size: var(--admonition-title-font-size, 0.8125rem);
#   font-weight: 500;
#   line-height: 1.3;
#   margin: 0 -0.5rem 0.5rem;
#   padding: 0.4rem 0.5rem 0.4rem 2rem;
#   position: relative;
# }
# blockquote p:has(> .notebook-admonition-title)::before {
#   color: var(--notebook-admonition-color);
#   content: "✎";
#   left: 0.65rem;
#   position: absolute;
# }
# .notebook-admonition-title {
#   font-weight: inherit;
# }
# table:not(.dataframe) {
#   border: 1px solid var(--docs-hairline, rgba(128, 128, 128, 0.35));
#   border-collapse: collapse;
# }
# table:not(.dataframe) th,
# table:not(.dataframe) td {
#   border: 1px solid var(--docs-hairline, rgba(128, 128, 128, 0.35));
# }
# </style>
#
# `PaintballPlot` shows many observations in statewide vote-share and seat-share space. The
# points may represent plans, elections, or modeled scenarios, as long as both sequences refer
# to the same observations in the same order.

# %%
from gerrytools.plotting import PaintballPlot

seats = [13, 15, 17, 21, 21, 14, 14, 15, 13, 16, 24, 24, 24, 24]
vote_shares = [
    0.5231,
    0.4782,
    0.5057,
    0.5674,
    0.5865,
    0.5007,
    0.5020,
    0.5174,
    0.4996,
    0.5169,
    0.5977,
    0.5948,
    0.5930,
    0.5650,
]

plot = PaintballPlot(legend=False)
plot.add_seats_votes_data(vote_shares, seats, total_seats=28)
plot.set_marker_options(color="cadmiumgreen")
plot.show()

# %% [markdown]
# The inputs above are Democratic shares. The plot
# complements both supplied shares before drawing them: an input point `(0.48, 5 / 14)` appears
# at `(0.52, 9 / 14)`. This convention lets Democratic input data be displayed as Republican
# vote and seat shares. When starting from seat counts, pass the chamber size with
# `total_seats=` instead.

# %% [markdown]
# ## Reference lines
#
# The proportionality and efficiency-gap helpers add common vote-seat references. Arbitrary
# lines through `(0.5, 0.5)` can be added with `add_lines_with_slope()`.

# %%
plot.add_efficiency_gap_line()
plot.add_proportionality_line()
plot.show()

# %% [markdown]
# ## Show the envelope
#
# `display_hull(True)` replaces the points with their horizontal envelope. At each observed
# seat-share level, it keeps the minimum and maximum vote-share coordinates and connects those
# bounds.

# %%
plot.display_hull(True)
plot.set_hull_options(color="lightblue", alpha=0.3, edgecolor="denim")
plot.show()

# %% [markdown]
# Shared axes, labels, legends, and output controls are covered in
# [shared statistical controls](options.ipynb).
#
# ## Related
#
# - [Seats-votes plots](seats_votes.ipynb)
# - [Plotting API](../../../api/plotting.rst)
